# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
load_dotenv()
# Out:
# True

# %%
@tool
def multiply(a: int, b:int) -> int:
    """Given two numbers a and b return the product"""
    return a*b

# %%
print(multiply.invoke({'a':3, 'b':5}))
# Out:
# 15

# %%
print(multiply.name)
# Out:
# multiply

# %%
# binding tool

# %%
llm = ChatGoogleGenerativeAI(model="models/gemini-2.5-flash")

# %%
llm_with_tools = llm.bind_tools([multiply])

# %%
llm_with_tools.invoke("Hello How are you?")
# Out:
# AIMessage(content=[{'type': 'text', 'text': "Hello! I'm an AI, so I don't have feelings, but I'm ready to help you. How can I assist you today?", 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f2a53-cfd8-7971-83d5-d946d0dae8c0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 56, 'output_tokens': 90, 'total_tokens': 146, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 58}})

# %%
llm_with_tools.invoke("can you multiply 6 and 2?").tool_calls[0]
# Out:
# {'name': 'multiply',
#  'args': {'b': 2, 'a': 6},
#  'id': 'd5188cb7-f69b-4bdf-8e69-811dc4c3cef5',
#  'type': 'tool_call'}
